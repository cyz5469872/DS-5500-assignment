# %%
# import necessary libs and load dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pokemon= pd.read_csv("C:/Users/yzcvo/Desktop/DS5500/pokemon/Pokemon.csv")

# %% [markdown]
# why I dont choose some kind of visual encoding

# %%
# I would to study about the speed of pokemons
pokemon_speed=pokemon["Speed"]
plt.plot(pokemon_speed)
plt.title("visualization of pokemon speed")
plt.show()

# %% [markdown]
# comment on the first visualization

# %%
plt.plot(pokemon_speed,'ro')
plt.title("pokemon speed visualization")
plt.show()

# %% [markdown]
# comment on the second visualization
